# %%
from os import listdir
import numpy as np
import re
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
CONFIG = 'Configuration'
TIME = 'average_elapsed_time'
OBJECTIVES = 'average_best_objective'
DIFF = 'diff_with_optimal'

# %%
instances = [
    'SpannerStronglyCorrelated_N_1000_R_100_0',
    'SpannerStronglyCorrelated_N_500_R_100_0',
    'SpannerStronglyCorrelated_N_100_R_100_0',
    'SpannerStronglyCorrelated_N_50_R_100_0',
    
    'StronglyCorrelated_N_1000_R_100_0',
    'StronglyCorrelated_N_500_R_100_0',
    'StronglyCorrelated_N_100_R_100_0',
    'StronglyCorrelated_N_50_R_100_0',
    
    'InverseCorrelated_N_1000_R_100_0',
    'InverseCorrelated_N_500_R_100_0',
    'InverseCorrelated_N_100_R_100_0',
    'InverseCorrelated_N_50_R_100_0',
    
    'Uncorrelated_N_1000_R_100_0',
    'Uncorrelated_N_500_R_100_0',
    'Uncorrelated_N_100_R_100_0',
    'Uncorrelated_N_50_R_100_0',
    
    'SubsetSum_N_1000_R_100_0',
    'SubsetSum_N_500_R_100_0',
    'SubsetSum_N_100_R_100_0',
    'SubsetSum_N_50_R_100_0',
]

# %%
path = '../data/'
machines = ['sleipnir', 'rayo']
pd.set_option('display.width', 1000)
for instance in instances:
    for machine in machines:
        print(f'\n\t\t\t\tInstancia: {instance} en {machine}\n')
        file = f'{path}{machine}/{instance}_{machine}.csv'
        df = pd.read_csv(file)
        df_sorted = df.sort_values(by=['diff_with_optimal'])
        print(df_sorted)
# Out:
# 				Instancia: SpannerStronglyCorrelated_N_1000_R_100_0 en sleipnir
#
#                                                    Configuration  average_best_objective  average_elapsed_time  diff_with_optimal
# 0                                                        Dynamic                 20613.0              0.029574                0.0
# 7    One-vs-OneGA_PopSize32_Evals500K_MR0.100000_CR_0.700000_SEQ                 18831.3             12.320180             1781.7
# 1  One-vs-OneGA_PopSize32_Evals500K_MR0.050000_CR_0.800000_OMP_2                 18817.3             10.917044             1795.7
# 8          SSGA_PopSize32_Evals500K_MR0.100000_CR_0.700000_OMP_2                 18812.3             12.486121             1800.7
# 4    One-vs-OneGA_PopSize32_Evals500K_MR0.050000_CR_0.800000_SEQ                 18805.7             11.075280             1807.3
# 6            SSGA_PopSize32_Evals500K_MR0.100000_CR_0.700000_SEQ                 18805.3             12.817227             1807.7
# ...
